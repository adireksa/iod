# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded["Employee-attrition.csv"]))
# Out:
#      <input type="file" id="files-46fd8181-9b0b-42de-9d19-019655064367" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46fd8181-9b0b-42de-9d19-019655064367">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Employee-attrition.csv to Employee-attrition.csv

# %%
df =pd.read_csv('/Users/lawrenceyim/Documents/Institute of Data/Labs/Mathematics/data/Employee-attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
data
# Out:
# array([[41, 'Yes', 'Travel_Rarely', ..., 4, 0, 5],
#        [49, 'No', 'Travel_Frequently', ..., 7, 1, 7],
#        [37, 'Yes', 'Travel_Rarely', ..., 0, 0, 0],
#        ...,
#        [27, 'No', 'Travel_Rarely', ..., 2, 0, 3],
#        [49, 'No', 'Travel_Frequently', ..., 6, 0, 8],
#        [34, 'No', 'Travel_Rarely', ..., 3, 1, 2]], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A:
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
# A:
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
#A:
df.dtypes.value_counts()
# Out:
# int64     26
# object     9
# dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
df.info()
#df.info gives info on col index, no. of non-null values so you can identify if you need to clean those columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
# A:
df['JobRole'].value_counts()
#'job title' not present in the df supplied
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
# A:
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
#A
def row_count():
    rows = len(df.axes[0])
    return print("Rows: " + str(rows))

# %%
row_count()
# Out:
# Rows: 1470

# %%
def row_count(column_name):
    number_of_rows = len(df[column_name])
    number_of_unique_rows = df[column_name].value_counts()
    return number_of_rows, number_of_unique_rows

print(row_count('JobRole'))
# Out:
# (1470, Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64)

# %%
df.rename(columns = {'JobRole':'job_title'}, inplace = True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'job_title', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.rename(columns = {'job_title':'JobRole'}, inplace = True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
# A:
df['Age'].describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
#A
#gives description on numeric col
df.describe(exclude=[object])
# Out:
#                Age    DailyRate  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  1470.000000  1470.000000  ...              1470.000000           1470.000000
# mean     36.923810   802.485714  ...                 2.187755              4.123129
# std       9.135373   403.509100  ...                 3.222430              3.568136
# min      18.000000   102.000000  ...                 0.000000              0.000000
# 25%      30.000000   465.000000  ...                 0.000000              2.000000
# 50%      36.000000   802.000000  ...                 1.000000              3.000000
# 75%      43.000000  1157.000000  ...                 3.000000              7.000000
# max      60.000000  1499.000000  ...                15.000000             17.000000
#
# [8 rows x 26 columns]

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
# A:
meaningful_df = pd.read_csv('/Users/lawrenceyim/Documents/Institute of Data/Labs/Mathematics/data/Employee-attrition.csv', index_col='EmployeeNumber')
meaningful_df
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# ...             ...       ...                ...        ...
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %%
df.set_index('EmployeeNumber', inplace=True)

# %%
df.sort_index()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# ...             ...       ...                ...        ...
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %%
df
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# ...             ...       ...                ...        ...
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
# A:
meaningful_df.iloc[0]
#matches the above for first row entry
# Out:
# Age                                      41
# Attrition                               Yes
# BusinessTravel                Travel_Rarely
# DailyRate                              1102
# Department                            Sales
# DistanceFromHome                          1
# Education                                 2
# EducationField                Life Sciences
# EmployeeCount                             1
# EnvironmentSatisfaction                   2
# Gender                               Female
# HourlyRate                               94
# JobInvolvement                            3
# JobLevel                                  2
# JobRole                     Sales Executive
# JobSatisfaction                           4
# MaritalStatus                        Single
# MonthlyIncome                          5993
# MonthlyRate                           19479
# NumCompaniesWorked                        8
# Over18                                    Y
# ...

# %%
df.iloc[100]
# Out:
# Age                                      37
# Attrition                               Yes
# BusinessTravel                Travel_Rarely
# DailyRate                               807
# Department                  Human Resources
# DistanceFromHome                          6
# Education                                 4
# EducationField              Human Resources
# EmployeeCount                             1
# EnvironmentSatisfaction                   3
# Gender                                 Male
# HourlyRate                               63
# JobInvolvement                            3
# JobLevel                                  1
# JobRole                     Human Resources
# JobSatisfaction                           1
# MaritalStatus                      Divorced
# MonthlyIncome                          2073
# MonthlyRate                           23648
# NumCompaniesWorked                        4
# Over18                                    Y
# ...

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
# A:
#able to sort by ascending/descending
df.sort_index(ascending=True)
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# ...             ...       ...                ...        ...
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
# A:
df.sort_values(["Age"], ascending=True)
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1839             18        No         Non-Travel       1431
# 614              18       Yes  Travel_Frequently       1306
# 1368             18        No         Non-Travel       1124
# 411              18        No      Travel_Rarely        812
# 405              18       Yes      Travel_Rarely        230
# ...             ...       ...                ...        ...
# 732              60        No      Travel_Rarely       1179
# 573              60        No  Travel_Frequently       1499
# 549              60        No      Travel_Rarely        422
# 1233             60        No      Travel_Rarely        696
# 1697             60        No      Travel_Rarely        370
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1839            Research & Development                14          3
# 614                              Sales                 5          3
# ...

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
# A:
df.sample()
# Out:
#                 Age Attrition BusinessTravel  DailyRate  \
# EmployeeNumber
# 346              29        No  Travel_Rarely        665
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 346             Research & Development                15          3
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# 346             Life Sciences              1                        3  ...
#
#                RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# EmployeeNumber
# 346                                   1             80                 0
#
#                 TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# EmployeeNumber
# 346                             6                     1                3
#
#                YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# ...

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
#as no cell in the database has a value of CEO. We will create it, by subsituting all Managers to be CEO
#replacement_df = meaningful_df["JobRole"].replace({"Manager": "CEO"}, inplace=True)
replacement_df = meaningful_df.replace(to_replace="Manager", value="CEO")
#replacement_df['JobRole']

# %%
df.loc[df['JobRole'] == 'Manager']
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 23               53        No      Travel_Rarely       1219
# 32               53        No      Travel_Rarely       1282
# 38               46        No      Travel_Rarely        705
# 84               55        No      Travel_Rarely        836
# 140              59        No         Non-Travel       1420
# ...             ...       ...                ...        ...
# 1900             48        No  Travel_Frequently        117
# 1938             58        No      Travel_Rarely        605
# 1973             55        No      Travel_Rarely        189
# 2022             39        No         Non-Travel        105
# 2031             42        No      Travel_Rarely        300
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 23                               Sales                 2          4
# 32              Research & Development                 5          3
# ...

# %%
replacement_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1470 entries, 1 to 2068
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
replacement_df['JobRole']
# Out:
# EmployeeNumber
# 1                 Sales Executive
# 2              Research Scientist
# 4           Laboratory Technician
# 5              Research Scientist
# 7           Laboratory Technician
#                   ...
# 2061        Laboratory Technician
# 2062    Healthcare Representative
# 2064       Manufacturing Director
# 2065              Sales Executive
# 2068        Laboratory Technician
# Name: JobRole, Length: 1470, dtype: object

# %%
# A:
replacement_df.loc[meaningful_df['JobRole'] == "CEO"]
#cross checked values. it works
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 23               53        No      Travel_Rarely       1219
# 32               53        No      Travel_Rarely       1282
# 38               46        No      Travel_Rarely        705
# 84               55        No      Travel_Rarely        836
# 140              59        No         Non-Travel       1420
# ...             ...       ...                ...        ...
# 1900             48        No  Travel_Frequently        117
# 1938             58        No      Travel_Rarely        605
# 1973             55        No      Travel_Rarely        189
# 2022             39        No         Non-Travel        105
# 2031             42        No      Travel_Rarely        300
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 23                               Sales                 2          4
# 32              Research & Development                 5          3
# ...

# %% [markdown]
# #### 4.B Group By Age

# %%
# A:
age_group = meaningful_df.groupby('Age')
age_group.first() #check first entries to crosscheck ans
# Out:
#     Attrition     BusinessTravel  DailyRate              Department  \
# Age
# 18        Yes      Travel_Rarely        230  Research & Development
# 19        Yes      Travel_Rarely        528                   Sales
# 20        Yes  Travel_Frequently        871  Research & Development
# 21         No      Travel_Rarely        391  Research & Development
# 22         No         Non-Travel       1123  Research & Development
# 23         No      Travel_Rarely        541                   Sales
# 24         No         Non-Travel        673  Research & Development
# 25        Yes      Travel_Rarely        240                   Sales
# 26        Yes      Travel_Rarely       1357  Research & Development
# 27         No      Travel_Rarely        591  Research & Development
# 28        Yes      Travel_Rarely        103  Research & Development
# 29         No      Travel_Rarely        153  Research & Development
# 30         No      Travel_Rarely       1358  Research & Development
# ...

# %% [markdown]
# # 5. Visualization
#
# > Indented block
#
#
#
# #### 5.A Plot Histogram of Age

# %%
# A:
meaningful_df.hist(column='Age')
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:
meaningful_df.boxplot(column='Age')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
# A:
meaningful_df.plot.scatter(x='Age', y='YearsAtCompany')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='YearsAtCompany'>

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
# A: as there is no store_name here we will use 'Department'
#meaningful_df.hist(column='Department')
ax = df.Department.value_counts().plot.bar(title='Department Employee Count')
ax.set_xlabel("Department Name")
ax.set_ylabel("# of Employee")
_ = plt.show()

# %%
plt.hist(df.Department, bins=3)
# Out:
# (array([446., 961.,  63.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %%
meaningful_df.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
print("statistical summary of the observation: ", stats.describe(df['Age']))
# Out:
# statistical summary of the observation:  DescribeResult(nobs=1470, minmax=(18, 60), mean=36.923809523809524, variance=83.45504878602223, skewness=0.41286446154785084, kurtosis=-0.40685066033188644)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
